# %% [markdown]
# DISCLAIMER: Some parts of this notebook require manually downloading data from external sources (e.g., PredictorData2023.xlsx from Amit Goyal's webpage). These files are not included in the repository. If these files are unavailable, certain cells will fail to execute. Users should download the required data files and place them in the same directory as the notebook before running those cells.
